# %%
#to perform sum and print type
a =int(input('Enter a number 1'))
b =float(input('Enter a number 2 in float'))
sum=a+b
print(sum)
print(type(sum))
# Out:
# Enter a number 12
# Enter a number 2 in float4.5
# 6.5
# <class 'float'>

# %%
a = ((1, 2, 3), [4, 5, 6], {"a": 7, "b": 8})
print(a)
print(a[2])
# Out:
# ((1, 2, 3), [4, 5, 6], {'a': 7, 'b': 8})
# {'a': 7, 'b': 8}

# %%
nested_dict = {
    "name": "Alice",
    "scores": {"math": 90, "science": 85},
    "hobbies": ["reading", "gaming"]
}
print(nested_dict["scores"]["math"])  # Accessing nested dictionary value
# Out:
# 90

# %%
nested_list = [[1, 2, 3], ["a", "b", "c"], {"key1": "value1", "key2": "value2"}]
print(nested_list[0])  # Access first nested list
# Out:
# [1, 2, 3]

# %%
nested_set = {1, 2, (3, 4, 5)}  # Tuples can be inside sets
print(nested_set)
# Out:
# {1, 2, (3, 4, 5)}

# %%
#if-else statement:
x = 10
if x > 5:
    print("x is greater than 5")
else:
    print("x is not greater than 5")
# Out:
# x is greater than 5

# %%
#nested if statement
x = 15
if x > 10:
    print("x is greater than 10")
    if x > 20:
        print("x is greater than 20")
    else:
        print("x is between 10 and 20")
# Out:
# x is greater than 10
# x is between 10 and 20

# %%
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(3):  # Outer loop
    for j in range(2):  # Inner loop
      print(f"i={i}, j={j}")
# Out:
# i=0, j=0
# i=0, j=1
# i=1, j=0
# i=1, j=1
# i=2, j=0
# i=2, j=1

# %%
#fuction execution code
def add(a, b):
    return a + b

result = add(5, 3)  # Function Call
print(result)
# Out:
# 8

# %%
#arguments and keywords in fn
def introduce(name, age):
    print(f"My name is {name} and I am {age} years old.")

introduce(age=25, name="Bob")  # Order does not matter
# Out:
# My name is Bob and I am 25 years old.

# %%
def greet(name="Guest"):
    print(f"Hello, {name}!")

greet()  # Uses default value
greet("Alice")  # Uses provided value
greet('shagun')
# Out:
# Hello, Guest!
# Hello, Alice!
# Hello, shagun!
